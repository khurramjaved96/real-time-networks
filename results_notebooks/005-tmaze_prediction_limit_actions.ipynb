# %% [markdown]
# # T-Maze with terminating episodes
#
# Thought that maybe the problem is due to long episodes. So I terminated the episodes at max 10 steps.

# %%
import mariadb
import sys
import pandas as pd
import numpy as np
import plotly
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import os

# JupyterLab renderer support
#jupyter labextension install jupyterlab-plotly@4.14.3

# OPTIONAL: Jupyter widgets extension
#jupyter labextension install @jupyter-widgets/jupyterlab-manager plotlywidget@4.14.3

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(
rc={
 'axes.axisbelow': False,
 'axes.edgecolor': 'black',
 'axes.facecolor': 'None',
 'axes.grid': False,
 'axes.labelcolor': 'black',
 'axes.spines.right': True,
 'axes.spines.top': True,
 'figure.facecolor': 'white',
 'lines.solid_capstyle': 'round',
 'patch.edgecolor': 'w',
 'patch.force_edgecolor': True,
 'text.color': 'black',
 'xtick.bottom': False,
 'xtick.color': 'black',
 'xtick.direction': 'out',
 'xtick.top': False,
 'ytick.color': 'black',
 'ytick.direction': 'out',
 'ytick.left': False,
 'ytick.right': False})
plt.rcParams["figure.figsize"] = (10,7)
sns.set_context("notebook", rc={"font.size":20,
                                "axes.titlesize":20,
                                "axes.labelsize":15})

#CB91_Blue = '#2CBDFE'
#CB91_Green = '#47DBCD'
#CB91_Pink = '#F3A0F2'
#CB91_Purple = '#9D2EC5'
#CB91_Violet = '#661D98'
#CB91_Amber = '#F5B14C'
#color_list = [CB91_Purple, CB91_Blue, CB91_Pink, CB91_Green,
#              CB91_Amber, CB91_Violet]
#plt.rcParams['axes.prop_cycle'] = plt.cycler(color=color_list)

# %%
class DbAccessor:
    def __init__(self, db_name, cfg_primary_key="run", timestep_col_name="episode"):
        #params:
        #    cfg_primary_key: the key that is used to index the runs
        #    timestep_col_name: the column which contains the timestep values to be used in plots (or any other column to index with/use as x-axis)
        self.cfg_primary_key = cfg_primary_key
        self.timestep_col_name = timestep_col_name
        try:
            self.conn = mariadb.connect(user='hshah1',
                                        password=os.environ['cedarsqlpswd'],
                                        host='127.0.0.1',
                                        port=3307,
                                        database=db_name)
        except mariadb.Error as e:
            print(f"Error connecting to MariaDB Platform: {e}")
            sys.exit(1)

    def get_table_list(self):
        return pd.read_sql('show tables', self.conn)
    
    def get_table(self, table_name, cfg_filter=None, column_names="*", index=True):
        #params:
        #    cfg_filter: optional value of <cfg_primary_key> to filter the results with
        #    column_names: can be multiple
        #    index: whether the current table is indexed by <timestep_col_name>
        #returns:
        #    <timestep_col_name>'s values + <column_names>'s values
        
        #TODO careful with column names in future...
        if index:
            if column_names != "*":
                column_names += f',{self.timestep_col_name}'

            if cfg_filter:
                return pd.read_sql(f'SELECT {column_names} FROM {table_name} WHERE {self.cfg_primary_key}={cfg_filter}', self.conn).set_index(self.timestep_col_name)
            else:
                return pd.read_sql(f'SELECT {column_names} FROM {table_name}', self.conn).set_index(self.timestep_col_name)            
        else:
            if cfg_filter:
                return pd.read_sql(f'SELECT {column_names} FROM {table_name} WHERE {self.cfg_primary_key}={cfg_filter}', self.conn)
            else:
                return pd.read_sql(f'SELECT {column_names} FROM {table_name}', self.conn)

# %%
db = DbAccessor('hshah1_tmaze_prediction')
pd.set_option('display.max_columns', 500)
pd.read_sql(f'select * from runs inner join run_states on runs.run=run_states.run where comment="limit_actions"', db.conn)
# Out:
#    add_features        comment data_driven_initialization  epsilon  \
# 0         false  limit_actions                      false     0.05
# 1         false  limit_actions                      false     0.05
# 2         false  limit_actions                      false     0.05
# 3         false  limit_actions                      false     0.05
# 4         false  limit_actions                      false     0.05
# 5         false  limit_actions                      false     0.05
# 6         false  limit_actions                      false     0.05
# 7         false  limit_actions                      false     0.05
# 8         false  limit_actions                      false     0.05
# 9         false  limit_actions                      false     0.05
# 10        false  limit_actions                      false     0.05
# 11        false  limit_actions                      false     0.05
# 12        false  limit_actions                      false     0.05
# 13        false  limit_actions                      false     0.05
# 14        false  limit_actions                      false     0.05
# 15        false  limit_actions                      false     0.05
# 16        false  limit_actions                      false     0.05
# 17        false  limit_actions                      false     0.05
# 18        false  limit_actions                      false     0.05
# 19        false  limit_actions                      false     0.05
#
#     features_acc_thresh  features_min_timesteps  gamma  max_episodes  \
# 0                   0.9                  100000   0.98        400000
# 1                   0.9                  100000   0.98        400000
# 2                   0.9                  100000   0.98        400000
# 3                   0.9                  100000   0.98        400000
# 4                   0.9                  100000   0.98        400000
# 5                   0.9                  100000   0.98        400000
# 6                   0.9                  100000   0.98        400000
# 7                   0.9                  100000   0.98        400000
# 8                   0.9                  100000   0.98        400000
# 9                   0.9                  100000   0.98        400000
# 10                  0.9                  100000   0.98        400000
# 11                  0.9                  100000   0.98        400000
# 12                  0.9                  100000   0.98        400000
# 13                  0.9                  100000   0.98        400000
# 14                  0.9                  100000   0.98        400000
# 15                  0.9                  100000   0.98        400000
# 16                  0.9                  100000   0.98        400000
# 17                  0.9                  100000   0.98        400000
# 18                  0.9                  100000   0.98        400000
# 19                  0.9                  100000   0.98        400000
#
#                 name  num_layers  num_new_features prediction_problem  run  \
# 0   tmaze_prediction          10                 5               true   21
# 1   tmaze_prediction          10                 5               true   22
# 2   tmaze_prediction          10                 5               true   23
# 3   tmaze_prediction          10                 5               true   24
# 4   tmaze_prediction          10                 5               true   25
# 5   tmaze_prediction          10                 5               true   26
# 6   tmaze_prediction          10                 5               true   27
# 7   tmaze_prediction          10                 5               true   28
# 8   tmaze_prediction          10                 5               true   29
# 9   tmaze_prediction          10                 5               true   30
# 10  tmaze_prediction          10                 5               true   31
# 11  tmaze_prediction          10                 5               true   32
# 12  tmaze_prediction          10                 5               true   33
# 13  tmaze_prediction          10                 5               true   34
# 14  tmaze_prediction          10                 5               true   35
# 15  tmaze_prediction          10                 5               true   36
# 16  tmaze_prediction          10                 5               true   37
# 17  tmaze_prediction          10                 5               true   38
# 18  tmaze_prediction          10                 5               true   39
# 19  tmaze_prediction          10                 5               true   40
#
#     seed  sparsity step_size    steps  tmaze_corridor_length  width  run  \
# 0      2         0      3e-5  6500000                      2     10   21
# 1      3         0      3e-5  6500000                      2     10   22
# 2      4         0      3e-5  6500000                      2     10   23
# 3      5         0      3e-5  6500000                      2     10   24
# 4      1         0      3e-5  6500000                      3     10   25
# 5      2         0      3e-5  6500000                      3     10   26
# 6      3         0      3e-5  6500000                      3     10   27
# 7      4         0      3e-5  6500000                      3     10   28
# 8      5         0      3e-5  6500000                      3     10   29
# 9      1         0      3e-5  6500000                      2     10   30
# 10     2         0      3e-5  3500000                      4     10   31
# 11     3         0      3e-5  3500000                      4     10   32
# 12     4         0      3e-5  3500000                      4     10   33
# 13     5         0      3e-5  3500000                      4     10   34
# 14     1         0      3e-5  3500000                      5     10   35
# 15     2         0      3e-5  3500000                      5     10   36
# 16     3         0      3e-5  3500000                      5     10   37
# 17     4         0      3e-5  3500000                      5     10   38
# 18     5         0      3e-5  3500000                      5     10   39
# 19     1         0      3e-5  3500000                      4     10   40
#
#    run_state run_state_comments
# 0   finished
# 1   finished
# 2   finished
# 3     killed     nan_prediction
# 4   finished
# 5   finished
# 6     killed     nan_prediction
# 7   finished
# 8     killed     nan_prediction
# 9   finished
# 10  finished
# 11    killed     nan_prediction
# 12  finished
# 13  finished
# 14  finished
# 15  finished
# 16  finished
# 17  finished
# 18  finished
# 19  finished

# %% [markdown]
# # T-Maze len 2

# %%
plt.title('(1) T-Maze len=2')
plt.xlabel('episode')
plt.ylabel('accuracy')
for k in [30,21,22,23,24]:
    plt.plot(db.get_table('episodic_metrics', k, 'accuracy'), label=k)
plt.legend()
plt.show()

# %%
plt.title('(2) T-Maze len=2')
plt.xlabel('episode')
plt.ylabel('timesteps')
for k in [30,21,22,23,24]:
    plt.plot(db.get_table('episodic_metrics', k, 'timestep'), label=k)
plt.legend()
plt.show()

# %%
plt.title('(3) T-Maze len=2')
plt.xlabel('episode')
plt.ylabel('Average cummulative reward per episode')
for k in [30,21,22,23,24]:
    plt.plot(db.get_table('episodic_metrics', k, 'avg_reward'), label=k)
plt.legend()
plt.show()

# %% [markdown]
# # T-Maze len 3

# %%
plt.title('(4) T-Maze len=3')
plt.xlabel('episode')
plt.ylabel('accuracy')
for k in range(25,30):
    plt.plot(db.get_table('episodic_metrics', k, 'accuracy'), label=k)
plt.legend()
plt.show()

# %%
plt.title('(5) T-Maze len=3')
plt.xlabel('episode')
plt.ylabel('timesteps')
for k in range(25,30):
    plt.plot(db.get_table('episodic_metrics', k, 'timestep'), label=k)
plt.legend()
plt.show()

# %%
plt.title('(6) T-Maze len=3')
plt.xlabel('episode')
plt.ylabel('Average cummulative reward per episode')
for k in range(25,30):
    plt.plot(db.get_table('episodic_metrics', k, 'avg_reward'), label=k)
plt.legend()
plt.show()

# %% [markdown]
# # T-Maze len 4

# %%
plt.title('(7) T-Maze len=4')
plt.xlabel('episode')
plt.ylabel('accuracy')
for k in [40,31,32,33,34]:
    plt.plot(db.get_table('episodic_metrics', k, 'accuracy'), label=k)
plt.legend()
plt.show()

# %%
plt.title('(8) T-Maze len=4')
plt.xlabel('episode')
plt.ylabel('timesteps')
for k in [40,31,32,33,34]:
    plt.plot(db.get_table('episodic_metrics', k, 'timestep'), label=k)
plt.legend()
plt.show()

# %%
plt.title('(9) T-Maze len=4')
plt.xlabel('episode')
plt.ylabel('Average cummulative reward per episode')
for k in [40,31,32,33,34]:
    plt.plot(db.get_table('episodic_metrics', k, 'avg_reward'), label=k)
plt.legend()
plt.show()

# %% [markdown]
# # T-Maze len 5

# %%
plt.title('(10) T-Maze len=5')
plt.xlabel('episode')
plt.ylabel('accuracy')
for k in range(35,40):
    plt.plot(db.get_table('episodic_metrics', k, 'accuracy'), label=k)
plt.legend()
plt.show()

# %%
plt.title('(11) T-Maze len=5')
plt.xlabel('episode')
plt.ylabel('timesteps')
for k in range(35,40):
    plt.plot(db.get_table('episodic_metrics', k, 'timestep'), label=k)
plt.legend()
plt.show()

# %%
plt.title('(12) T-Maze len=5')
plt.xlabel('episode')
plt.ylabel('Average cummulative reward per episode')
for k in range(35,40):
    plt.plot(db.get_table('episodic_metrics', k, 'avg_reward'), label=k)
plt.legend()
plt.show()

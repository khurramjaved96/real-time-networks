# %% [markdown]
# # T-Maze as a prediction problem (comparison with baseline LSTMs)
#
# Optimal actions are picked in the corridor. At T-junction, the learned e-greedy policy is used to pick actions.
#
# Here the only actions available to be learned and picked are the two actions at T-Junctions. So the sequence length remains fixed.

# %% [markdown]
# * RTNN uses the traces whereas the baseline does not
# * Didnt reset the trace at end of each episode
# * Although it shouldnt really influence the results much here, the terminal update bug is present.
# * No-op actions arent used in rtnn whereas they are used in baseline. There is still a delay in RTNN qvalues so it should be roughly equivalent.
#
# TODO run baseline with traces and without no-op.

# %%
import mariadb
import sys
import pandas as pd
import numpy as np
import plotly
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import os

# JupyterLab renderer support
#jupyter labextension install jupyterlab-plotly@4.14.3

# OPTIONAL: Jupyter widgets extension
#jupyter labextension install @jupyter-widgets/jupyterlab-manager plotlywidget@4.14.3

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(
rc={
 'axes.axisbelow': False,
 'axes.edgecolor': 'black',
 'axes.facecolor': 'None',
 'axes.grid': False,
 'axes.labelcolor': 'black',
 'axes.spines.right': True,
 'axes.spines.top': True,
 'figure.facecolor': 'white',
 'lines.solid_capstyle': 'round',
 'patch.edgecolor': 'w',
 'patch.force_edgecolor': True,
 'text.color': 'black',
 'xtick.bottom': False,
 'xtick.color': 'black',
 'xtick.direction': 'out',
 'xtick.top': False,
 'ytick.color': 'black',
 'ytick.direction': 'out',
 'ytick.left': False,
 'ytick.right': False})
plt.rcParams["figure.figsize"] = (10,7)
sns.set_context("notebook", rc={"font.size":20,
                                "axes.titlesize":20,
                                "axes.labelsize":15})

#CB91_Blue = '#2CBDFE'
#CB91_Green = '#47DBCD'
#CB91_Pink = '#F3A0F2'
#CB91_Purple = '#9D2EC5'
#CB91_Violet = '#661D98'
#CB91_Amber = '#F5B14C'
#color_list = [CB91_Purple, CB91_Blue, CB91_Pink, CB91_Green,
#              CB91_Amber, CB91_Violet]
#plt.rcParams['axes.prop_cycle'] = plt.cycler(color=color_list)

# %%
class DbAccessor:
    def __init__(self, db_name, cfg_primary_key="run", timestep_col_name="episode", local=False):
        #params:
        #    cfg_primary_key: the key that is used to index the runs
        #    timestep_col_name: the column which contains the timestep values to be used in plots (or any other column to index with/use as x-axis)
        self.cfg_primary_key = cfg_primary_key
        self.timestep_col_name = timestep_col_name
        try:
            if local:
                    self.conn = mariadb.connect(user="haseebs",
                                                password="",
                                                host="localhost",
                                                port=3306,
                                                database=db_name)
            else:
                self.conn = mariadb.connect(user='hshah1',
                                            password=os.environ['cedarsqlpswd'],
                                            host='127.0.0.1',
                                            port=3307,
                                            database=db_name)
        except mariadb.Error as e:
            print(f"Error connecting to MariaDB Platform: {e}")
            sys.exit(1)

    def get_table_list(self):
        return pd.read_sql('show tables', self.conn)
    
    def get_table(self, table_name, cfg_filter=None, column_names="*", index=True):
        #params:
        #    cfg_filter: optional value of <cfg_primary_key> to filter the results with
        #    column_names: can be multiple
        #    index: whether the current table is indexed by <timestep_col_name>
        #returns:
        #    <timestep_col_name>'s values + <column_names>'s values
        
        #TODO careful with column names in future...
        if index:
            if column_names != "*":
                column_names += f',{self.timestep_col_name}'

            if cfg_filter:
                return pd.read_sql(f'SELECT {column_names} FROM {table_name} WHERE {self.cfg_primary_key}={cfg_filter}', self.conn).set_index(self.timestep_col_name)
            else:
                return pd.read_sql(f'SELECT {column_names} FROM {table_name}', self.conn).set_index(self.timestep_col_name)            
        else:
            if cfg_filter:
                return pd.read_sql(f'SELECT {column_names} FROM {table_name} WHERE {self.cfg_primary_key}={cfg_filter}', self.conn)
            else:
                return pd.read_sql(f'SELECT {column_names} FROM {table_name}', self.conn)

# %%
db = DbAccessor('hshah1_baselines1', local=True)
pd.set_option('display.max_columns', 500)
comment = 'pred'
pd.read_sql(f'select * from runs where comment="{comment}"', db.conn)
#pd.read_sql(f'select * from runs inner join run_states on runs.run=run_states.run where comment="{comment}"', db.conn)
# Out:
#     seed  v  w  gpus               name comment  \
# 0    0.0  0  0   1.0  hshah1_baselines1    pred
# 1    1.0  0  0   1.0  hshah1_baselines1    pred
# 2    2.0  0  0   1.0  hshah1_baselines1    pred
# 3    3.0  0  0   1.0  hshah1_baselines1    pred
# 4    4.0  0  0   1.0  hshah1_baselines1    pred
# 5    0.0  0  0   1.0  hshah1_baselines1    pred
# 6    1.0  0  0   1.0  hshah1_baselines1    pred
# 7    2.0  0  0   1.0  hshah1_baselines1    pred
# 8    3.0  0  0   1.0  hshah1_baselines1    pred
# 9    4.0  0  0   1.0  hshah1_baselines1    pred
# 10   0.0  0  0   1.0  hshah1_baselines1    pred
# 11   1.0  0  0   1.0  hshah1_baselines1    pred
# 12   2.0  0  0   1.0  hshah1_baselines1    pred
# 13   3.0  0  0   1.0  hshah1_baselines1    pred
# 14   4.0  0  0   1.0  hshah1_baselines1    pred
# 15   0.0  0  0   1.0  hshah1_baselines1    pred
# 16   1.0  0  0   1.0  hshah1_baselines1    pred
# 17   2.0  0  0   1.0  hshah1_baselines1    pred
# 18   3.0  0  0   1.0  hshah1_baselines1    pred
# 19   4.0  0  0   1.0  hshah1_baselines1    pred
# 20   1.0  0  0   1.0  hshah1_baselines1    pred
# 21   2.0  0  0   1.0  hshah1_baselines1    pred
# 22   3.0  0  0   1.0  hshah1_baselines1    pred
# 23   4.0  0  0   1.0  hshah1_baselines1    pred
# 24   0.0  0  0   1.0  hshah1_baselines1    pred
# 25   1.0  0  0   1.0  hshah1_baselines1    pred
# 26   2.0  0  0   1.0  hshah1_baselines1    pred
# 27   3.0  0  0   1.0  hshah1_baselines1    pred
# 28   4.0  0  0   1.0  hshah1_baselines1    pred
# 29   0.0  0  0   1.0  hshah1_baselines1    pred
#
#                                     output_dir   run  INPUT_SIZE  OUTPUT_SIZE  \
# 0   results/23May2021/hshah1_baselines1/0/5_3/   0.0         3.0          4.0
# 1   results/23May2021/hshah1_baselines1/0/5_2/   1.0         3.0          4.0
# 2   results/23May2021/hshah1_baselines1/0/5_1/   2.0         3.0          4.0
# 3   results/23May2021/hshah1_baselines1/0/5_5/   3.0         3.0          4.0
# 4   results/23May2021/hshah1_baselines1/0/5_4/   4.0         3.0          4.0
# 5   results/23May2021/hshah1_baselines1/1/5_1/   5.0         3.0          4.0
# 6   results/23May2021/hshah1_baselines1/1/5_2/   6.0         3.0          4.0
# 7   results/23May2021/hshah1_baselines1/1/5_3/   7.0         3.0          4.0
# 8   results/23May2021/hshah1_baselines1/1/5_4/   8.0         3.0          4.0
# 9   results/23May2021/hshah1_baselines1/1/5_5/   9.0         3.0          4.0
# 10  results/23May2021/hshah1_baselines1/2/5_1/  10.0         3.0          4.0
# 11  results/23May2021/hshah1_baselines1/2/5_2/  11.0         3.0          4.0
# 12  results/23May2021/hshah1_baselines1/2/5_3/  12.0         3.0          4.0
# 13  results/23May2021/hshah1_baselines1/2/5_4/  13.0         3.0          4.0
# 14  results/23May2021/hshah1_baselines1/2/5_5/  14.0         3.0          4.0
# 15  results/23May2021/hshah1_baselines1/3/5_1/  15.0         3.0          4.0
# 16  results/23May2021/hshah1_baselines1/3/5_2/  16.0         3.0          4.0
# 17  results/23May2021/hshah1_baselines1/3/5_3/  17.0         3.0          4.0
# 18  results/23May2021/hshah1_baselines1/3/5_4/  18.0         3.0          4.0
# 19  results/23May2021/hshah1_baselines1/3/5_5/  19.0         3.0          4.0
# 20  results/23May2021/hshah1_baselines1/4/5_2/  21.0         3.0          4.0
# 21  results/23May2021/hshah1_baselines1/4/5_1/  22.0         3.0          4.0
# 22  results/23May2021/hshah1_baselines1/4/5_3/  23.0         3.0          4.0
# 23  results/23May2021/hshah1_baselines1/4/5_4/  24.0         3.0          4.0
# 24  results/23May2021/hshah1_baselines1/5/5_2/  25.0         3.0          4.0
# 25  results/23May2021/hshah1_baselines1/5/5_1/  26.0         3.0          4.0
# 26  results/23May2021/hshah1_baselines1/5/5_3/  27.0         3.0          4.0
# 27  results/23May2021/hshah1_baselines1/5/5_4/  28.0         3.0          4.0
# 28  results/23May2021/hshah1_baselines1/5/5_5/  29.0         3.0          4.0
# 29  results/23May2021/hshah1_baselines1/6/5_1/  30.0         3.0          4.0
#
#     HIDDEN_L_SIZE  STEP_SIZE  TBPTT_T  ADAMB1  ADAMB2         ADAME  LAMBDA  \
# 0            10.0     0.0003     10.0     0.9   0.999  1.000000e-08     0.0
# 1            10.0     0.0003     10.0     0.9   0.999  1.000000e-08     0.0
# 2            10.0     0.0003     10.0     0.9   0.999  1.000000e-08     0.0
# 3            10.0     0.0003     10.0     0.9   0.999  1.000000e-08     0.0
# 4            10.0     0.0003     10.0     0.9   0.999  1.000000e-08     0.0
# 5            10.0     0.0003     10.0     0.9   0.999  1.000000e-08     0.0
# 6            10.0     0.0003     10.0     0.9   0.999  1.000000e-08     0.0
# 7            10.0     0.0003     10.0     0.9   0.999  1.000000e-08     0.0
# 8            10.0     0.0003     10.0     0.9   0.999  1.000000e-08     0.0
# 9            10.0     0.0003     10.0     0.9   0.999  1.000000e-08     0.0
# 10           10.0     0.0003     10.0     0.9   0.999  1.000000e-08     0.0
# 11           10.0     0.0003     10.0     0.9   0.999  1.000000e-08     0.0
# 12           10.0     0.0003     10.0     0.9   0.999  1.000000e-08     0.0
# 13           10.0     0.0003     10.0     0.9   0.999  1.000000e-08     0.0
# 14           10.0     0.0003     10.0     0.9   0.999  1.000000e-08     0.0
# 15           10.0     0.0003     10.0     0.9   0.999  1.000000e-08     0.0
# 16           10.0     0.0003     10.0     0.9   0.999  1.000000e-08     0.0
# 17           10.0     0.0003     10.0     0.9   0.999  1.000000e-08     0.0
# 18           10.0     0.0003     10.0     0.9   0.999  1.000000e-08     0.0
# 19           10.0     0.0003     10.0     0.9   0.999  1.000000e-08     0.0
# 20           10.0     0.0003     10.0     0.9   0.999  1.000000e-08     0.0
# 21           10.0     0.0003     10.0     0.9   0.999  1.000000e-08     0.0
# 22           10.0     0.0003     10.0     0.9   0.999  1.000000e-08     0.0
# 23           10.0     0.0003     10.0     0.9   0.999  1.000000e-08     0.0
# 24           10.0     0.0003     10.0     0.9   0.999  1.000000e-08     0.0
# 25           10.0     0.0003     10.0     0.9   0.999  1.000000e-08     0.0
# 26           10.0     0.0003     10.0     0.9   0.999  1.000000e-08     0.0
# 27           10.0     0.0003     10.0     0.9   0.999  1.000000e-08     0.0
# 28           10.0     0.0003     10.0     0.9   0.999  1.000000e-08     0.0
# 29           10.0     0.0003     10.0     0.9   0.999  1.000000e-08     0.0
#
#     GAMMA  N_TRAIN_STEPS  EPISODES  MAX_EPISODE_LENGTH  EPISODE_GAP  EPSILON  \
# 0    0.98      2000000.0  150000.0              1000.0          1.0     0.05
# 1    0.98      2000000.0  150000.0              1000.0          1.0     0.05
# 2    0.98      2000000.0  150000.0              1000.0          1.0     0.05
# 3    0.98      2000000.0  150000.0              1000.0          1.0     0.05
# 4    0.98      2000000.0  150000.0              1000.0          1.0     0.05
# 5    0.98      2000000.0  150000.0              1000.0          1.0     0.05
# 6    0.98      2000000.0  150000.0              1000.0          1.0     0.05
# 7    0.98      2000000.0  150000.0              1000.0          1.0     0.05
# 8    0.98      2000000.0  150000.0              1000.0          1.0     0.05
# 9    0.98      2000000.0  150000.0              1000.0          1.0     0.05
# 10   0.98      2000000.0  150000.0              1000.0          1.0     0.05
# 11   0.98      2000000.0  150000.0              1000.0          1.0     0.05
# 12   0.98      2000000.0  150000.0              1000.0          1.0     0.05
# 13   0.98      2000000.0  150000.0              1000.0          1.0     0.05
# 14   0.98      2000000.0  150000.0              1000.0          1.0     0.05
# 15   0.98      2000000.0  150000.0              1000.0          1.0     0.05
# 16   0.98      2000000.0  150000.0              1000.0          1.0     0.05
# 17   0.98      2000000.0  150000.0              1000.0          1.0     0.05
# 18   0.98      2000000.0  150000.0              1000.0          1.0     0.05
# 19   0.98      2000000.0  150000.0              1000.0          1.0     0.05
# 20   0.98      2000000.0  150000.0              1000.0          1.0     0.05
# 21   0.98      2000000.0  150000.0              1000.0          1.0     0.05
# 22   0.98      2000000.0  150000.0              1000.0          1.0     0.05
# 23   0.98      2000000.0  150000.0              1000.0          1.0     0.05
# 24   0.98      2000000.0  150000.0              1000.0          1.0     0.05
# 25   0.98      2000000.0  150000.0              1000.0          1.0     0.05
# 26   0.98      2000000.0  150000.0              1000.0          1.0     0.05
# 27   0.98      2000000.0  150000.0              1000.0          1.0     0.05
# 28   0.98      2000000.0  150000.0              1000.0          1.0     0.05
# 29   0.98      2000000.0  150000.0              1000.0          1.0     0.05
#
#     TMAZE_CORRIDOR_LENGTH PREDICTION_PROBLEM USE_NO_OPS
# 0                     2.0                  1          1
# 1                     2.0                  1          1
# 2                     2.0                  1          1
# 3                     2.0                  1          1
# 4                     2.0                  1          1
# 5                     3.0                  1          1
# 6                     3.0                  1          1
# 7                     3.0                  1          1
# 8                     3.0                  1          1
# 9                     3.0                  1          1
# 10                    4.0                  1          1
# 11                    4.0                  1          1
# 12                    4.0                  1          1
# 13                    4.0                  1          1
# 14                    4.0                  1          1
# 15                    5.0                  1          1
# 16                    5.0                  1          1
# 17                    5.0                  1          1
# 18                    5.0                  1          1
# 19                    5.0                  1          1
# 20                   15.0                  1          1
# 21                   15.0                  1          1
# 22                   15.0                  1          1
# 23                   15.0                  1          1
# 24                   25.0                  1          1
# 25                   25.0                  1          1
# 26                   25.0                  1          1
# 27                   25.0                  1          1
# 28                   25.0                  1          1
# 29                   15.0                  1          1

# %%
db1 = DbAccessor('hshah1_tmaze_adaptive_new1', local=False)
pd.set_option('display.max_columns', 500)
comment1 = 'trace_pred_hacky_fix'
comment2 = 'trace_pred_hacky_fix45'
pd.read_sql(f'select * from runs where comment="{comment1}" or comment="{comment2}"', db1.conn)
# Out:
#    add_features                 comment  episode_gap  episode_length  epsilon  \
# 0          true    trace_pred_hacky_fix            8            1000     0.05
# 1          true    trace_pred_hacky_fix            8            1000     0.05
# 2          true    trace_pred_hacky_fix            8            1000     0.05
# 3          true    trace_pred_hacky_fix            8            1000     0.05
# 4          true    trace_pred_hacky_fix            8            1000     0.05
# 5          true    trace_pred_hacky_fix            8            1000     0.05
# 6          true    trace_pred_hacky_fix            8            1000     0.05
# 7          true    trace_pred_hacky_fix            8            1000     0.05
# 8          true    trace_pred_hacky_fix            8            1000     0.05
# 9          true    trace_pred_hacky_fix            8            1000     0.05
# 10         true    trace_pred_hacky_fix            8            1000     0.05
# 11         true    trace_pred_hacky_fix            8            1000     0.05
# 12         true    trace_pred_hacky_fix            8            1000     0.05
# 13         true    trace_pred_hacky_fix            8            1000     0.05
# 14         true    trace_pred_hacky_fix            8            1000     0.05
# 15         true    trace_pred_hacky_fix            8            1000     0.05
# 16         true    trace_pred_hacky_fix            8            1000     0.05
# 17         true    trace_pred_hacky_fix            8            1000     0.05
# 18         true    trace_pred_hacky_fix            8            1000     0.05
# 19         true    trace_pred_hacky_fix            8            1000     0.05
# 20         true  trace_pred_hacky_fix45            8            1000     0.05
# 21         true  trace_pred_hacky_fix45            8            1000     0.05
# 22         true  trace_pred_hacky_fix45            8            1000     0.05
# 23         true  trace_pred_hacky_fix45            8            1000     0.05
# 24         true  trace_pred_hacky_fix45            8            1000     0.05
# 25         true  trace_pred_hacky_fix45            8            1000     0.05
# 26         true  trace_pred_hacky_fix45            8            1000     0.05
# 27         true  trace_pred_hacky_fix45            8            1000     0.05
# 28         true  trace_pred_hacky_fix45            8            1000     0.05
# 29         true  trace_pred_hacky_fix45            8            1000     0.05
#
#     features_min_timesteps  gamma  lambda  max_episodes                 name  \
# 0                    80000   0.98    0.98       1000000  tmaze_adaptive_new1
# 1                    80000   0.98    0.98       1000000  tmaze_adaptive_new1
# 2                    80000   0.98    0.98       1000000  tmaze_adaptive_new1
# 3                    80000   0.98    0.98       1000000  tmaze_adaptive_new1
# 4                    80000   0.98    0.98       1000000  tmaze_adaptive_new1
# 5                    80000   0.98    0.98       1000000  tmaze_adaptive_new1
# 6                    80000   0.98    0.98       1000000  tmaze_adaptive_new1
# 7                    80000   0.98    0.98       1000000  tmaze_adaptive_new1
# 8                    80000   0.98    0.98       1000000  tmaze_adaptive_new1
# 9                    80000   0.98    0.98       1000000  tmaze_adaptive_new1
# 10                   80000   0.98    0.98       1000000  tmaze_adaptive_new1
# 11                   80000   0.98    0.98       1000000  tmaze_adaptive_new1
# 12                   80000   0.98    0.98       1000000  tmaze_adaptive_new1
# 13                   80000   0.98    0.98       1000000  tmaze_adaptive_new1
# 14                   80000   0.98    0.98       1000000  tmaze_adaptive_new1
# 15                   80000   0.98    0.98       1000000  tmaze_adaptive_new1
# 16                   80000   0.98    0.98       1000000  tmaze_adaptive_new1
# 17                   80000   0.98    0.98       1000000  tmaze_adaptive_new1
# 18                   80000   0.98    0.98       1000000  tmaze_adaptive_new1
# 19                   80000   0.98    0.98       1000000  tmaze_adaptive_new1
# 20                   80000   0.98    0.98       1000000  tmaze_adaptive_new1
# 21                   80000   0.98    0.98       1000000  tmaze_adaptive_new1
# 22                   80000   0.98    0.98       1000000  tmaze_adaptive_new1
# 23                   80000   0.98    0.98       1000000  tmaze_adaptive_new1
# 24                   80000   0.98    0.98       1000000  tmaze_adaptive_new1
# 25                   80000   0.98    0.98       1000000  tmaze_adaptive_new1
# 26                   80000   0.98    0.98       1000000  tmaze_adaptive_new1
# 27                   80000   0.98    0.98       1000000  tmaze_adaptive_new1
# 28                   80000   0.98    0.98       1000000  tmaze_adaptive_new1
# 29                   80000   0.98    0.98       1000000  tmaze_adaptive_new1
#
#     num_layers  num_new_features prediction_problem  run  seed step_size  \
# 0            0                10               true   21     2      3e-5
# 1            0                10               true   22     3      3e-5
# 2            0                10               true   23     4      3e-5
# 3            0                10               true   24     5      3e-5
# 4            0                10               true   25     1      3e-5
# 5            0                10               true   26     2      3e-5
# 6            0                10               true   27     3      3e-5
# 7            0                10               true   28     4      3e-5
# 8            0                10               true   29     5      3e-5
# 9            0                10               true   30     1      3e-5
# 10           0                10               true   31     2      3e-5
# 11           0                10               true   32     3      3e-5
# 12           0                10               true   33     4      3e-5
# 13           0                10               true   34     5      3e-5
# 14           0                10               true   35     1      3e-5
# 15           0                10               true   36     2      3e-5
# 16           0                10               true   37     3      3e-5
# 17           0                10               true   38     4      3e-5
# 18           0                10               true   39     5      3e-5
# 19           0                10               true   40     1      3e-5
# 20           0                10               true   41     2      3e-5
# 21           0                10               true   42     3      3e-5
# 22           0                10               true   43     4      3e-5
# 23           0                10               true   44     5      3e-5
# 24           0                10               true   45     1      3e-5
# 25           0                10               true   46     2      3e-5
# 26           0                10               true   47     3      3e-5
# 27           0                10               true   48     4      3e-5
# 28           0                10               true   49     5      3e-5
# 29           0                10               true   50     1      3e-5
#
#         steps  tmaze_corridor_length  width
# 0   800000000                      2      0
# 1   800000000                      2      0
# 2   800000000                      2      0
# 3   800000000                      2      0
# 4   800000000                      3      0
# 5   800000000                      3      0
# 6   800000000                      3      0
# 7   800000000                      3      0
# 8   800000000                      3      0
# 9   800000000                      4      0
# 10  800000000                      4      0
# 11  800000000                      4      0
# 12  800000000                      4      0
# 13  800000000                      4      0
# 14  800000000                      5      0
# 15  800000000                      5      0
# 16  800000000                      5      0
# 17  800000000                      5      0
# 18  800000000                      5      0
# 19  800000000                      2      0
# 20  800000000                      4      0
# 21  800000000                      4      0
# 22  800000000                      4      0
# 23  800000000                      4      0
# 24  800000000                      5      0
# 25  800000000                      5      0
# 26  800000000                      5      0
# 27  800000000                      5      0
# 28  800000000                      5      0
# 29  800000000                      4      0

# %%
def plot_runs(tmaze_len, db_base, db_rtnn, runs_base, runs_rtnn):
    plt.title(f'T-Maze len={tmaze_len}')
    plt.xlabel('episode')
    plt.ylabel('accuracy')
    for k in runs_base:
        plt.plot(db_base.get_table('episodic_metrics', k[0], 'accuracy'), label="BPTT", color="red")
    for k in runs_rtnn:
        plt.plot(db_rtnn.get_table('episodic_metrics', k[0], 'accuracy')[0:50000], label="RTNN", color="blue")
    plt.legend()
    plt.show()

# %% [markdown]
# # T-Maze len 2

# %%
tmaze_len = 2
runs_base = pd.read_sql(f'select run,seed from runs where comment="{comment}" and tmaze_corridor_length={tmaze_len}', db.conn).values[1:]
runs_rtnn = pd.read_sql(f'select run,seed from runs where comment="{comment1}" and tmaze_corridor_length={tmaze_len} and step_size=3e-5', db1.conn).values
plot_runs(tmaze_len, db, db1, runs_base, runs_rtnn)

# %% [markdown]
# # T-Maze len 3

# %%
tmaze_len = 3
runs_base = pd.read_sql(f'select run,seed from runs where comment="{comment}" and tmaze_corridor_length={tmaze_len}', db.conn).values
runs_rtnn = pd.read_sql(f'select run,seed from runs where comment="{comment1}" and tmaze_corridor_length={tmaze_len}', db1.conn).values
plot_runs(tmaze_len, db, db1, runs_base, runs_rtnn)

# %% [markdown]
# # T-Maze len 4

# %%
tmaze_len = 4
runs_base = pd.read_sql(f'select run,seed from runs where comment="{comment}" and tmaze_corridor_length={tmaze_len}', db.conn).values
runs_rtnn = pd.read_sql(f'select run,seed from runs where comment="{comment2}" and tmaze_corridor_length={tmaze_len}', db1.conn).values
plot_runs(tmaze_len, db, db1, runs_base, runs_rtnn)

# %% [markdown]
# # T-Maze len 5

# %%
tmaze_len = 5
runs_base = pd.read_sql(f'select run,seed from runs where comment="{comment}" and tmaze_corridor_length={tmaze_len}', db.conn).values
runs_rtnn = pd.read_sql(f'select run,seed from runs where comment="{comment2}" and tmaze_corridor_length={tmaze_len}', db1.conn).values
plot_runs(tmaze_len, db, db1, runs_base, runs_rtnn)
